# %%
# Programming Exercise1

# . Submit the GitHub link for your solution, which should contain the source code,

# datasets generated, and any other relevant material).
# Write a program to generate an Erdӧs-Renyi (E-R) network G(n, p), were for at least three input configurations, i.e., three set of
# values for n and p. For instance, one such configuration could be n = 7 ∗ 106
# and p = 10−2

# . For each configuration, calculate
# the following network properties and compare them with the theoretical prediction for an Erdӧs-Renyi network with the same
# configuration. Run each configuration at least 30 times and report the average estimates for each configuration.
# i. The average degree of the network.
# ii. Average clustering coefficient of the network.
# iii. The average path length.
# iv. Plot the degree distribution for the three chosen configurations. Do they center on the average degree? 
import math 
import matplotlib.pyplot as plt
import networkx as nx

# %%
def Average_degree(n,p):
    averageDegree = (n-1) * p
    return averageDegree

# %%
def Average_clustering_coefficient(n,p):
    G = nx.erdos_renyi_graph(n,p)
    clustering = nx.algorithms.cluster.average_clustering(G)
    return clustering

# %%
def Average_path_length(n,p):
    averageDegree = Average_degree(n,p)
    APL = ((math.log(n)) // (math.log(averageDegree)))
    return APL

# %%
def Degree_distribution(n,p):
    G = nx.erdos_renyi_graph(n,p)
    degrees_dict = {}

    for n in G.nodes():
        degree = G.degree(n)
        if degree not in degrees_dict:
            degrees_dict[degree] = 0
        degrees_dict[degree] += 1
    items = sorted(degrees_dict.items())

    plt.plot([k for (k, v) in items], [v for (k, v) in items])
    
    plt.xlabel('degree (k)')
    plt.show()
    return items

# %%
def inputs(n,p):
    for i in range (len(n)):
        for j in range (1,30):
                print( "<k> of n" , i ,"and p" ,i ,": ", Average_degree(n[i],p[i]))
                print( "clustering of n" , i ,"and p" , i ,": " , Average_clustering_coefficient(n[i],p[i]))
                print( "apl of n" ,i ,"and p" ,i ,": " , Average_path_length(n[i],p[i]))
                if 1 <= j <= 5:
                    print( "degree_distribution of n" ,i ,"and p" ,i ,": " , Degree_distribution(n[i],p[i]))

            

inputs([10**2,10**3,1400], [0.03,0.009,0.3])
# Out:
# <k> of n 0 and p 0 :  2.9699999999999998
# clustering of n 0 and p 0 :  0.06268253968253966
# apl of n 0 and p 0 :  4.0
# degree_distribution of n 0 and p 0 :  [(0, 5), (1, 9), (2, 23), (3, 23), (4, 24), (5, 9), (6, 6), (7, 1)]
# <k> of n 0 and p 0 :  2.9699999999999998
# clustering of n 0 and p 0 :  0.0
# apl of n 0 and p 0 :  4.0
# degree_distribution of n 0 and p 0 :  [(0, 3), (1, 12), (2, 23), (3, 20), (4, 18), (5, 13), (6, 8), (7, 1), (8, 2)]
# <k> of n 0 and p 0 :  2.9699999999999998
# clustering of n 0 and p 0 :  0.02157142857142857
# apl of n 0 and p 0 :  4.0
# degree_distribution of n 0 and p 0 :  [(0, 4), (1, 11), (2, 20), (3, 28), (4, 19), (5, 8), (6, 7), (7, 1), (8, 2)]
# <k> of n 0 and p 0 :  2.9699999999999998
# clustering of n 0 and p 0 :  0.02773809523809524
# apl of n 0 and p 0 :  4.0
# degree_distribution of n 0 and p 0 :  [(0, 3), (1, 9), (2, 27), (3, 21), (4, 16), (5, 10), (6, 12), (7, 2)]
# <k> of n 0 and p 0 :  2.9699999999999998
# clustering of n 0 and p 0 :  0.022849206349206348
# apl of n 0 and p 0 :  4.0
# degree_distribution of n 0 and p 0 :  [(0, 3), (1, 14), (2, 23), (3, 20), (4, 21), (5, 11), (6, 4), (7, 2), (8, 1), (9, 1)]
# <k> of n 0 and p 0 :  2.9699999999999998
# clustering of n 0 and p 0 :  0.034833333333333334
# apl of n 0 and p 0 :  4.0
# <k> of n 0 and p 0 :  2.9699999999999998
# clustering of n 0 and p 0 :  0.03
# apl of n 0 and p 0 :  4.0
# <k> of n 0 and p 0 :  2.9699999999999998
# clustering of n 0 and p 0 :  0.03528571428571429
# apl of n 0 and p 0 :  4.0
# <k> of n 0 and p 0 :  2.9699999999999998
# clustering of n 0 and p 0 :  0.03247619047619048
# apl of n 0 and p 0 :  4.0
# <k> of n 0 and p 0 :  2.9699999999999998
# clustering of n 0 and p 0 :  0.013444444444444443
# apl of n 0 and p 0 :  4.0
# <k> of n 0 and p 0 :  2.9699999999999998
# clustering of n 0 and p 0 :  0.014190476190476189
# apl of n 0 and p 0 :  4.0
# <k> of n 0 and p 0 :  2.9699999999999998
# clustering of n 0 and p 0 :  0.009999999999999998
# apl of n 0 and p 0 :  4.0
# <k> of n 0 and p 0 :  2.9699999999999998
# clustering of n 0 and p 0 :  0.039086580086580086
# apl of n 0 and p 0 :  4.0
# <k> of n 0 and p 0 :  2.9699999999999998
# clustering of n 0 and p 0 :  0.009333333333333332
# apl of n 0 and p 0 :  4.0
# <k> of n 0 and p 0 :  2.9699999999999998
# clustering of n 0 and p 0 :  0.03823809523809524
# apl of n 0 and p 0 :  4.0
# <k> of n 0 and p 0 :  2.9699999999999998
# clustering of n 0 and p 0 :  0.022500000000000006
# apl of n 0 and p 0 :  4.0
# <k> of n 0 and p 0 :  2.9699999999999998
# clustering of n 0 and p 0 :  0.0061428571428571435
# apl of n 0 and p 0 :  4.0
# <k> of n 0 and p 0 :  2.9699999999999998
# clustering of n 0 and p 0 :  0.05014285714285714
# apl of n 0 and p 0 :  4.0
# <k> of n 0 and p 0 :  2.9699999999999998
# clustering of n 0 and p 0 :  0.004809523809523809
# apl of n 0 and p 0 :  4.0
# <k> of n 0 and p 0 :  2.9699999999999998
# clustering of n 0 and p 0 :  0.0506904761904762
# apl of n 0 and p 0 :  4.0
# <k> of n 0 and p 0 :  2.9699999999999998
# clustering of n 0 and p 0 :  0.017181818181818184
# apl of n 0 and p 0 :  4.0
# <k> of n 0 and p 0 :  2.9699999999999998
# clustering of n 0 and p 0 :  0.033690476190476194
# apl of n 0 and p 0 :  4.0
# <k> of n 0 and p 0 :  2.9699999999999998
# clustering of n 0 and p 0 :  0.03283333333333334
# apl of n 0 and p 0 :  4.0
# <k> of n 0 and p 0 :  2.9699999999999998
# clustering of n 0 and p 0 :  0.027333333333333338
# apl of n 0 and p 0 :  4.0
# <k> of n 0 and p 0 :  2.9699999999999998
# clustering of n 0 and p 0 :  0.012476190476190476
# apl of n 0 and p 0 :  4.0
# <k> of n 0 and p 0 :  2.9699999999999998
# clustering of n 0 and p 0 :  0.016619047619047624
# apl of n 0 and p 0 :  4.0
# <k> of n 0 and p 0 :  2.9699999999999998
# clustering of n 0 and p 0 :  0.038452380952380946
# apl of n 0 and p 0 :  4.0
# <k> of n 0 and p 0 :  2.9699999999999998
# clustering of n 0 and p 0 :  0.019880952380952385
# apl of n 0 and p 0 :  4.0
# <k> of n 0 and p 0 :  2.9699999999999998
# clustering of n 0 and p 0 :  0.006
# apl of n 0 and p 0 :  4.0
# <k> of n 1 and p 1 :  8.991
# clustering of n 1 and p 1 :  0.007998223431195562
# apl of n 1 and p 1 :  3.0
# degree_distribution of n 1 and p 1 :  [(1, 1), (2, 2), (3, 13), (4, 28), (5, 67), (6, 82), (7, 113), (8, 121), (9, 142), (10, 124), (11, 98), (12, 77), (13, 61), (14, 27), (15, 19), (16, 19), (17, 4), (19, 2)]
# <k> of n 1 and p 1 :  8.991
# clustering of n 1 and p 1 :  0.008667163306249996
# apl of n 1 and p 1 :  3.0
# degree_distribution of n 1 and p 1 :  [(1, 1), (2, 5), (3, 17), (4, 39), (5, 51), (6, 85), (7, 113), (8, 121), (9, 154), (10, 119), (11, 97), (12, 71), (13, 56), (14, 36), (15, 15), (16, 12), (17, 5), (19, 1), (20, 2)]
# <k> of n 1 and p 1 :  8.991
# clustering of n 1 and p 1 :  0.010303580690035804
# apl of n 1 and p 1 :  3.0
# degree_distribution of n 1 and p 1 :  [(1, 1), (2, 3), (3, 17), (4, 23), (5, 60), (6, 107), (7, 107), (8, 129), (9, 142), (10, 111), (11, 104), (12, 80), (13, 51), (14, 29), (15, 25), (16, 5), (17, 4), (18, 1), (19, 1)]
# <k> of n 1 and p 1 :  8.991
# clustering of n 1 and p 1 :  0.009482552131391146
# apl of n 1 and p 1 :  3.0
# degree_distribution of n 1 and p 1 :  [(0, 1), (2, 3), (3, 14), (4, 35), (5, 52), (6, 94), (7, 121), (8, 131), (9, 143), (10, 115), (11, 102), (12, 70), (13, 53), (14, 26), (15, 18), (16, 9), (17, 7), (18, 4), (19, 2)]
# <k> of n 1 and p 1 :  8.991
# clustering of n 1 and p 1 :  0.010005152982552369
# apl of n 1 and p 1 :  3.0
# degree_distribution of n 1 and p 1 :  [(1, 2), (2, 1), (3, 16), (4, 33), (5, 65), (6, 103), (7, 130), (8, 133), (9, 121), (10, 113), (11, 111), (12, 69), (13, 37), (14, 38), (15, 16), (16, 8), (17, 3), (23, 1)]
# <k> of n 1 and p 1 :  8.991
# clustering of n 1 and p 1 :  0.010182247972186061
# apl of n 1 and p 1 :  3.0
# <k> of n 1 and p 1 :  8.991
# clustering of n 1 and p 1 :  0.006750359813531161
# apl of n 1 and p 1 :  3.0
# <k> of n 1 and p 1 :  8.991
# clustering of n 1 and p 1 :  0.008781384301972534
# apl of n 1 and p 1 :  3.0
# <k> of n 1 and p 1 :  8.991
# clustering of n 1 and p 1 :  0.009014933020196167
# apl of n 1 and p 1 :  3.0
# <k> of n 1 and p 1 :  8.991
# clustering of n 1 and p 1 :  0.009172522455184991
# apl of n 1 and p 1 :  3.0
# <k> of n 1 and p 1 :  8.991
# clustering of n 1 and p 1 :  0.01092672413585726
# apl of n 1 and p 1 :  3.0
# <k> of n 1 and p 1 :  8.991
# clustering of n 1 and p 1 :  0.007932430314783252
# apl of n 1 and p 1 :  3.0
# <k> of n 1 and p 1 :  8.991
# clustering of n 1 and p 1 :  0.009245713677447424
# apl of n 1 and p 1 :  3.0
# <k> of n 1 and p 1 :  8.991
# clustering of n 1 and p 1 :  0.008182378560551928
# apl of n 1 and p 1 :  3.0
# <k> of n 1 and p 1 :  8.991
# clustering of n 1 and p 1 :  0.01137174811772336
# apl of n 1 and p 1 :  3.0
# <k> of n 1 and p 1 :  8.991
# clustering of n 1 and p 1 :  0.009234341724666806
# apl of n 1 and p 1 :  3.0
# <k> of n 1 and p 1 :  8.991
# clustering of n 1 and p 1 :  0.009896169482392397
# apl of n 1 and p 1 :  3.0
# <k> of n 1 and p 1 :  8.991
# clustering of n 1 and p 1 :  0.00938091870290013
# apl of n 1 and p 1 :  3.0
# <k> of n 1 and p 1 :  8.991
# clustering of n 1 and p 1 :  0.01111686042715455
# apl of n 1 and p 1 :  3.0
# <k> of n 1 and p 1 :  8.991
# clustering of n 1 and p 1 :  0.008861179343532281
# apl of n 1 and p 1 :  3.0
# <k> of n 1 and p 1 :  8.991
# clustering of n 1 and p 1 :  0.009464531873355402
# apl of n 1 and p 1 :  3.0
# <k> of n 1 and p 1 :  8.991
# clustering of n 1 and p 1 :  0.007783092715677849
# apl of n 1 and p 1 :  3.0
# <k> of n 1 and p 1 :  8.991
# clustering of n 1 and p 1 :  0.008024677163222046
# apl of n 1 and p 1 :  3.0
# <k> of n 1 and p 1 :  8.991
# clustering of n 1 and p 1 :  0.00898567163830322
# apl of n 1 and p 1 :  3.0
# <k> of n 1 and p 1 :  8.991
# clustering of n 1 and p 1 :  0.008665202126734637
# apl of n 1 and p 1 :  3.0
# <k> of n 1 and p 1 :  8.991
# clustering of n 1 and p 1 :  0.007713745293234453
# apl of n 1 and p 1 :  3.0
# <k> of n 1 and p 1 :  8.991
# clustering of n 1 and p 1 :  0.009390913704458596
# apl of n 1 and p 1 :  3.0
# <k> of n 1 and p 1 :  8.991
# clustering of n 1 and p 1 :  0.009118796236443297
# apl of n 1 and p 1 :  3.0
# <k> of n 1 and p 1 :  8.991
# clustering of n 1 and p 1 :  0.008778961369690265
# apl of n 1 and p 1 :  3.0
# <k> of n 2 and p 2 :  419.7
# clustering of n 2 and p 2 :  0.3005563067754812
# apl of n 2 and p 2 :  1.0
# degree_distribution of n 2 and p 2 :  [(353, 1), (362, 1), (371, 1), (372, 1), (373, 3), (375, 2), (376, 3), (377, 2), (378, 2), (379, 2), (380, 4), (381, 3), (382, 3), (383, 3), (384, 3), (385, 1), (386, 5), (387, 8), (388, 7), (389, 7), (390, 3), (391, 16), (392, 5), (393, 8), (394, 15), (395, 14), (396, 15), (397, 19), (398, 25), (399, 13), (400,